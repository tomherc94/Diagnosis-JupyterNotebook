# %%
# Importando Bibliotecas:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

from sklearn.cluster import KMeans

# %%
# Leitura de Dados no formato .CSV
names = ['Temperature_of_patient', 'Occurrence_of_nausea',
         'Lumbar_pain', 'Urine_pushing', 'Micturition_pains', 'Burning_of_urethra',
         'Decision']
df = pd.read_csv('diagnosis.csv', names=names)

# Número de linhas e colunas:
df.shape
# Out:
# (120, 7)

# %%
# Estatística Descritiva:
df.describe()
# Out:
#        Temperature_of_patient
# count              120.000000
# mean                38.724167
# std                  1.819132
# min                 35.500000
# 25%                 37.100000
# 50%                 37.950000
# 75%                 40.600000
# max                 41.500000

# %%
# Tipos de Dados:
df.dtypes
# Out:
# Temperature_of_patient    float64
# Occurrence_of_nausea         bool
# Lumbar_pain                  bool
# Urine_pushing                bool
# Micturition_pains            bool
# Burning_of_urethra           bool
# Decision                   object
# dtype: object

# %%
# Verificando registros nulos:
df.isnull().sum()
# Out:
# Temperature_of_patient    0
# Occurrence_of_nausea      0
# Lumbar_pain               0
# Urine_pushing             0
# Micturition_pains         0
# Burning_of_urethra        0
# Decision                  0
# dtype: int64

# %%
# Definindo um estilo para os gráficos:
plt.style.use('fivethirtyeight')

# %%
# Verificando as distribuição dos dados:
plt.figure(1 , figsize = (15 , 6))
n = 0 
for x in ['Temperature_of_patient', 'Occurrence_of_nausea',
         'Lumbar_pain']:
    n += 1
    plt.subplot(1 , 3 , n)
    plt.subplots_adjust(hspace =0.5 , wspace = 0.5)
    sns.distplot(df[x] , bins = 25)
    plt.title('{} '.format(x))
plt.show()

# %%
# Verificando as distribuição dos dados:
plt.figure(1 , figsize = (15 , 6))
n = 0 
for x in ['Urine_pushing', 'Micturition_pains', 'Burning_of_urethra']:
    n += 1
    plt.subplot(1 , 3 , n)
    plt.subplots_adjust(hspace =0.5 , wspace = 0.5)
    sns.distplot(df[x] , bins = 25)
    plt.title('{} '.format(x))
plt.show()

# %%
# Contagem de Amostras por Decisão:
plt.figure(1 , figsize = (15 , 5))
sns.countplot(y = 'Decision' , data = df)
plt.show()

# %%
# Temperature_of_patient:
plt.figure(1 , figsize = (15 , 6))
for decision in ['HEALTHY' , 'IUB', 'IUB_NRP', 'NRP']:
    plt.scatter(x = 'Temperature_of_patient' , y = 'Temperature_of_patient' , data = df[df['Decision'] == decision] ,
                s = 200 , alpha = 1.0 , label = decision)
plt.xlabel('Temperature_of_patient'), plt.ylabel('Temperature_of_patient') 
plt.title('Temperature_of_patient')
plt.legend()
plt.show()

# %%
# Selecionando o número de clusters através do método Elbow (Soma das distâncias quadráticas intra clusters):
X2 = df[['Temperature_of_patient' , 'Micturition_pains']].iloc[: , :].values
inertia = []
for n in range(1 , 11):
    algorithm = (KMeans(n_clusters = n))
    algorithm.fit(X2)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5)
plt.xlabel('Número de Clusters') , plt.ylabel('Soma das Distâncias Q intra Clusters')
plt.show()

# %%
# Inicializando e Computando o KMeans com o valor de 4 clusters:
algorithm = (KMeans(n_clusters = 2))
algorithm.fit(X2)
# Out:
# KMeans(n_clusters=2)

# %%
# Visualizando os grupos criados e seus centroides:
labels2 = algorithm.labels_
centroids2 = algorithm.cluster_centers_

h = 0.02
x_min, x_max = X2[:, 0].min() - 1, X2[:, 0].max() + 1
y_min, y_max = X2[:, 1].min() - 1, X2[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()]) 

plt.figure(1 , figsize = (15 , 7) )
plt.clf()
Z2 = Z.reshape(xx.shape)
plt.imshow(Z2 , interpolation='nearest', extent=(xx.min(), xx.max(), yy.min(), yy.max()), cmap = plt.cm.Pastel2, aspect = 'auto', origin='lower')
plt.scatter( x = 'Temperature_of_patient' ,y = 'Decision' , data = df , c = labels2 , s = 200 )
plt.scatter(x = centroids2[: , 0] , y =  centroids2[: , 1] , s = 300 , c = 'red' , alpha = 1.0)
plt.ylabel('Decision') , plt.xlabel('Temperature_of_patient')
plt.show()

# %%
df["clusters"] = algorithm.labels_
df.head()
# Out:
#    Temperature_of_patient  Occurrence_of_nausea  Lumbar_pain  Urine_pushing  \
# 0                    35.5                 False         True          False
# 1                    35.9                 False        False           True
# 2                    40.0                  True         True           True
# 3                    40.0                  True         True           True
# 4                    40.0                  True         True           True
#
#    Micturition_pains  Burning_of_urethra Decision  clusters
# 0              False               False  HEALTHY         0
# 1               True                True      IUB         0
# 2               True                True  IUB_NRP         1
# 3               True                True  IUB_NRP         1
# 4               True               False  IUB_NRP         1

# %%
# Excluindo as colunas que não foram utilizadas:
df_group = df.drop(["Occurrence_of_nausea","Lumbar_pain",
                    "Urine_pushing","Burning_of_urethra"],axis=1).groupby("clusters")

# %%
# Estatística descritiva dos grupos:
df_group.describe()
# Out:
#          Temperature_of_patient                                               \
#                           count       mean       std   min   25%   50%   75%
# clusters
# 0                          67.0  37.216418  0.698613  35.5  36.8  37.2  37.7
# 1                          53.0  40.630189  0.567242  39.0  40.2  40.7  41.1
#
#
#            max
# clusters
# 0         38.9
# 1         41.5
